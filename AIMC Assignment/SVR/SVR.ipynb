# %%
#Import libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Car_Purchasing_Data.csv', sep=',' , encoding='latin-1')
#there was a UnicodeDecodeError and it was resolved by changing the encoding to latin-1

# %%
#Observing the dataset
dataset
# Out:
#        Customer Name                                    Customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           Country  Gender        Age  Annual Salary  Credit Card Debt  \
# ...

# %%
#Plotting graphs between annual salary, cc debt, net worth and car amt
X = dataset.iloc[ : , 5:-1]
y = dataset.iloc[ : , 8]

# %%
#fit_transform method in FS expects a 2D array => transform y into a 2D array

y = y.values.reshape(-1, 1)    #An attribute error was reported 'Series' object has no attribute 'reshape' => change in pd documentation

print(y)
# Out:
# [[35321.45877]
#  [45115.52566]
#  [42925.70921]
#  [67422.36313]
#  [55915.46248]
#  [56611.99784]
#  [28925.70549]
#  [47434.98265]
#  [48013.6141 ]
#  [38189.50601]
#  [59045.51309]
#  [42288.81046]
#  [28700.0334 ]
#  [49258.87571]
#  [49510.03356]
#  [53017.26723]
#  [41814.72067]
#  [43901.71244]
#  [44633.99241]
#  [54827.52403]
#  [51130.95379]
#  [43402.31525]
#  [47240.86004]
#  [46635.49432]
#  [45078.40193]
#  [44387.58412]
#  [37161.55393]
#  [49091.97185]
#  [58350.31809]
#  [43994.35972]
#  [17584.56963]
#  [44650.36073]
#  [66363.89316]
#  [53489.46214]
#  [39810.34817]
#  [51612.14311]
#  [38978.67458]
#  [10092.22509]
#  [35928.52404]
#  [54823.19221]
#  [45805.67186]
#  [41567.47033]
#  [28031.20985]
#  [27815.73813]
#  [68678.4352 ]
#  [68925.09447]
#  [34215.7615 ]
#  [37843.46619]
#  [37883.24231]
#  [48734.35708]
#  [27187.23914]
#  [63738.39065]
#  [48266.75516]
#  [46381.13111]
#  [31978.9799 ]
#  [48100.29052]
#  [47380.91224]
#  [41425.00116]
# ...

# %%
#Splitting into training and testing datasets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler() #use two diff scaler objects for the feature/dep_var since, the scaler objects notes the mean and median for the given input, which is different for these columns
X_train = sc_X.fit_transform(X_train)
y_train = sc_y.fit_transform(y_train)

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X_train,y_train)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
#Predicting test results
sc_y.inverse_transform(regressor.predict(sc_X.transform(X_test)))
# Out:
# array([34698.71398748, 46548.24474645, 33757.40516507, 48542.72772537,
#        44431.44705163, 45885.48803348, 61415.46899926, 52697.13507902,
#        26052.48900028, 41617.87631979, 46600.63318033, 49446.92962889,
#        62789.01039217, 58846.10473602, 22023.32410996, 31230.0522282 ,
#        46354.87223333, 42874.89978092, 42729.40755965, 25275.82802676,
#        44118.31806226, 40462.5666952 , 43686.07321359, 40651.93296513,
#        62633.61826522, 45011.96510208, 42394.32284447, 37093.15439325,
#        62254.36577257, 49050.73730416, 54528.59033301, 45047.3892175 ,
#        47554.18964069, 46283.94416083, 55336.09283768, 49527.09422567,
#        31560.6083825 , 53713.99670931, 37455.35573571, 38222.4071434 ,
#        49550.70302395, 35824.24328879, 39966.96236979, 49592.65187646,
#        37308.38396008, 46764.62574549, 45559.4196381 , 48448.29615929,
#        50162.23232769, 43882.16951417, 48594.20449889, 44780.19834191,
# ...
